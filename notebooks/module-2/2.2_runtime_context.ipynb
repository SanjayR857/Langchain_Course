# %%
from dotenv import load_dotenv
load_dotenv()
import os

# %%
from dataclasses import dataclass

@dataclass
class ColourContext:
    favourite_colour: str = "blue"
    least_favourite_colour: str = "yellow"

# %%
from langchain.agents import create_agent
from langchain_openai import AzureChatOpenAI

model = AzureChatOpenAI(
    azure_deployment=os.getenv("OPENAI_DEFAULT_DEPLOYMENT"),  # or your deployment
    api_version="2025-04-01-preview",  # or your api version
    azure_endpoint=os.getenv("OPENAI_ENDPOINT"),  # or your endpoint
)

agent = create_agent(
    model=model,
    context_schema=ColourContext  
)

# %%
from langchain.messages import HumanMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What is my favourite colour?")]},
    context=ColourContext()
)

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content='What is my favourite colour?', additional_kwargs={}, response_metadata={}, id='247661f0-6328-4c7e-8440-8da8cf7541db'),
#               AIMessage(content='I don’t know — you haven’t told me. If you want me to guess, I’d pick blue (it’s the most common favourite).  \n\nIf you’d rather have me work it out, answer any of these quick choices and I’ll infer a likely favourite:\n\n1) Ocean or forest?  \n2) Sunset or sunrise?  \n3) Bright neon or soft pastel?  \n4) Bold and energetic or calm and soothing?  \n5) Roses or lavender?  \n\nReply with your answers (1–5), or just tell me your favourite directly.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 379, 'prompt_tokens': 12, 'total_tokens': 391, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 256, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}, 'latency_checkpoint': {'engine_tbt_ms': 11, 'engine_ttft_ms': 34, 'engine_ttlt_ms': 4797, 'pre_inference_ms': 134, 'service_tbt_ms': 11, 'service_ttft_ms': 245, 'service_ttlt_ms': 5003, 'total_duration_ms': 4878, 'user_visible_ttft_ms': 111}}, 'model_provider': 'openai', 'model_name': 'gpt-5-mini-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DdyiZtnW7FB9Lu5hjw7Rp8PGYaDp3', 'service_tier': 'default', 'prompt_filter_results': [{'prompt_index': 0, 'content_filter_results': {'hate': {'filtered': False, 'severity': 'safe'}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}}}], 'finish_reason': 'stop', 'logprobs': None, 'content_filter_results': {'hate': {'filtered': False, 'severity': 'safe'}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}}}, id='lc_run--019e1220-382a-71b3-a380-c41e9a49e802-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 12, 'output_tokens': 379, 'total_tokens': 391, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 256}})]}

# %% [markdown]
# ## Accessing Context

# %%
from langchain.tools import tool, ToolRuntime

@tool
def get_favourite_colour(runtime: ToolRuntime) -> str:
    """Get the favourite colour of the user"""
    return runtime.context.favourite_colour

@tool
def get_least_favourite_colour(runtime: ToolRuntime) -> str:
    """Get the least favourite colour of the user"""
    return runtime.context.least_favourite_colour

# %%
agent = create_agent(
    model=model,
    tools=[get_favourite_colour, get_least_favourite_colour],
    context_schema=ColourContext
)

# %%
response = agent.invoke(
    {"messages": [HumanMessage(content="What is my favourite colour?")]},
    context=ColourContext()
)

pprint(response)
# Out:
# c:\Users\shash\Projects\Langchain_Course\.venv\Lib\site-packages\pydantic\main.py:464: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected `none` - serialized value may not be as expected [field_name='context', input_value=ColourContext(favourite_c...vourite_colour='yellow'), input_type=ColourContext])
#   return self.__pydantic_serializer__.to_python(
# {'messages': [HumanMessage(content='What is my favourite colour?', additional_kwargs={}, response_metadata={}, id='a65f1c5e-5446-4d50-8ab1-42b979d04d35'),
#               AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 86, 'prompt_tokens': 149, 'total_tokens': 235, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 64, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}, 'latency_checkpoint': {'engine_tbt_ms': 8, 'engine_ttft_ms': 34, 'engine_ttlt_ms': 801, 'pre_inference_ms': 103, 'service_tbt_ms': 3, 'service_ttft_ms': 935, 'service_ttlt_ms': 1228, 'total_duration_ms': 1132, 'user_visible_ttft_ms': 832}}, 'model_provider': 'openai', 'model_name': 'gpt-5-mini-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DdyjkyCexENtr9nGfCpn6L9Mbf09t', 'service_tier': 'default', 'prompt_filter_results': [{'prompt_index': 0, 'content_filter_results': {'hate': {'filtered': False, 'severity': 'safe'}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}}}], 'finish_reason': 'tool_calls', 'logprobs': None, 'content_filter_results': {}}, id='lc_run--019e1221-5271-7ef3-9163-d41f86cc9507-0', tool_calls=[{'name': 'get_favourite_colour', 'args': {}, 'id': 'call_0d8LBN7U0zRqXlyLY5wThQkq', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 149, 'output_tokens': 86, 'total_tokens': 235, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 64}}),
#               ToolMessage(content='blue', name='get_favourite_colour', id='0699a020-b705-4a7a-828c-ad1a32af2957', tool_call_id='call_0d8LBN7U0zRqXlyLY5wThQkq'),
#               AIMessage(content='Your favourite colour is blue. Would you like me to remember that or do anything with it?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 93, 'prompt_tokens': 178, 'total_tokens': 271, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 64, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}, 'latency_checkpoint': {'engine_tbt_ms': 11, 'engine_ttft_ms': 49, 'engine_ttlt_ms': 1603, 'pre_inference_ms': 115, 'service_tbt_ms': 11, 'service_ttft_ms': 506, 'service_ttlt_ms': 2052, 'total_duration_ms': 1943, 'user_visible_ttft_ms': 390}}, 'model_provider': 'openai', 'model_name': 'gpt-5-mini-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DdyjlogicnVxgJS51TvRb6JoppZRH', 'service_tier': 'default', 'prompt_filter_results': [{'prompt_index': 0, 'content_filter_results': {}}], 'finish_reason': 'stop', 'logprobs': None, 'content_filter_results': {'hate': {'filtered': False, 'severity': 'safe'}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}}}, id='lc_run--019e1221-5dc0-7b41-b624-52b55ff66c0b-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 178, 'output_tokens': 93, 'total_tokens': 271, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 64}})]}

# %%
response = agent.invoke(
    {"messages": [HumanMessage(content="What is my favourite colour?")]},
    context=ColourContext(favourite_colour="green")
)

pprint(response)
# Out:
# c:\Users\shash\Projects\Langchain_Course\.venv\Lib\site-packages\pydantic\main.py:464: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected `none` - serialized value may not be as expected [field_name='context', input_value=ColourContext(favourite_c...vourite_colour='yellow'), input_type=ColourContext])
#   return self.__pydantic_serializer__.to_python(
# {'messages': [HumanMessage(content='What is my favourite colour?', additional_kwargs={}, response_metadata={}, id='d8f98e5a-9b71-4b73-a20c-b05971196078'),
#               AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 86, 'prompt_tokens': 149, 'total_tokens': 235, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 64, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}, 'latency_checkpoint': {'engine_tbt_ms': 8, 'engine_ttft_ms': 31, 'engine_ttlt_ms': 849, 'pre_inference_ms': 106, 'service_tbt_ms': 8, 'service_ttft_ms': 312, 'service_ttlt_ms': 1126, 'total_duration_ms': 1027, 'user_visible_ttft_ms': 206}}, 'model_provider': 'openai', 'model_name': 'gpt-5-mini-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DdykjE4fWIbjKBdl1Yx74k74c7hrU', 'service_tier': 'default', 'prompt_filter_results': [{'prompt_index': 0, 'content_filter_results': {'hate': {'filtered': False, 'severity': 'safe'}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}}}], 'finish_reason': 'tool_calls', 'logprobs': None, 'content_filter_results': {}}, id='lc_run--019e1221-de3d-7393-b43e-291ef88fb712-0', tool_calls=[{'name': 'get_favourite_colour', 'args': {}, 'id': 'call_bb2lQHqhUdgn76LYjrLrY6eU', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 149, 'output_tokens': 86, 'total_tokens': 235, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 64}}),
#               ToolMessage(content='green', name='get_favourite_colour', id='3fe465d5-cccc-4dd6-80d8-c0e87b1acef9', tool_call_id='call_bb2lQHqhUdgn76LYjrLrY6eU'),
#               AIMessage(content='Your favourite colour is green. Would you like colour palettes, design ideas, or anything else in green?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 159, 'prompt_tokens': 178, 'total_tokens': 337, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 128, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}, 'latency_checkpoint': {'engine_tbt_ms': 7, 'engine_ttft_ms': 94, 'engine_ttlt_ms': 1286, 'pre_inference_ms': 164, 'service_tbt_ms': 7, 'service_ttft_ms': 594, 'service_ttlt_ms': 1781, 'total_duration_ms': 1625, 'user_visible_ttft_ms': 430}}, 'model_provider': 'openai', 'model_name': 'gpt-5-mini-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-Ddylhwc8bp3lwsOCLl2EKBPu5F6Yu', 'service_tier': 'default', 'prompt_filter_results': [{'prompt_index': 0, 'content_filter_results': {}}], 'finish_reason': 'stop', 'logprobs': None, 'content_filter_results': {'hate': {'filtered': False, 'severity': 'safe'}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}}}, id='lc_run--019e1222-4ca8-7d22-baf0-71dc4038e5ee-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 178, 'output_tokens': 159, 'total_tokens': 337, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 128}})]}

# %%
from dotenv import load_dotenv
load_dotenv()
import os 
from dataclasses import dataclass
from langchain_openai import AzureChatOpenAI
from langchain.agents import create_agent
from langchain.tools import tool, ToolRuntime


@dataclass
class ColourContext:
    favourite_colour: str = "blue"
    least_favourite_colour: str = "yellow"


@tool
def get_favourite_colour(runtime: ToolRuntime) -> str:
    """Get the favourite colour of the user"""
    return runtime.context.favourite_colour


@tool
def get_least_favourite_colour(runtime: ToolRuntime) -> str:
    """Get the least favourite colour of the user"""
    return runtime.context.least_favourite_colour


model = AzureChatOpenAI(
    azure_deployment=os.getenv("OPENAI_DEFAULT_DEPLOYMENT"),  # or your deployment
    api_version="2025-04-01-preview",  # or your api version
    azure_endpoint=os.getenv("OPENAI_ENDPOINT"),  # or your endpoint
)

agent = create_agent(
    model=model,
    tools=[get_favourite_colour, get_least_favourite_colour],
    context_schema=ColourContext
)

# %%
agent.invoke({"messages":"What is my favourite_colour"})
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 agent.invoke({"messages":"What is my favourite_colour"})
#
# File c:\Users\shash\Projects\Langchain_Course\.venv\Lib\site-packages\langgraph\pregel\main.py:3094, in Pregel.invoke(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, **kwargs)
#    3091 chunks: list[dict[str, Any] | Any] = []
#    3092 interrupts: list[Interrupt] = []
# -> 3094 for chunk in self.stream(
#    3095     input,
#    3096     config,
#    3097     context=context,
#    3098     stream_mode=["updates", "values"]
#    3099     if stream_mode == "values"
#    3100     else stream_mode,
#    3101     print_mode=print_mode,
#    3102     output_keys=output_keys,
#    3103     interrupt_before=interrupt_before,
#    3104     interrupt_after=interrupt_after,
#    3105     durability=durability,
#    3106     **kwargs,
#    3107 ):
#    3108     if stream_mode == "values":
#    3109         if len(chunk) == 2:
#
# File c:\Users\shash\Projects\Langchain_Course\.venv\Lib\site-packages\langgraph\pregel\main.py:2669, in Pregel.stream(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, subgraphs, debug, **kwargs)
#    2667 for task in loop.match_cached_writes():
#    2668     loop.output_writes(task.id, task.writes, cached=True)
# -> 2669 for _ in runner.tick(
#    2670     [t for t in loop.tasks.values() if not t.writes],
#    2671     timeout=self.step_timeout,
#    2672     get_waiter=get_waiter,
#    2673     schedule_task=loop.accept_push,
#    2674 ):
#    2675     # emit output
#    2676     yield from _output(
#    2677         stream_mode, print_mode, subgraphs, stream.get, queue.Empty
#    2678     )
#    2679 loop.after_tick()
#
# File c:\Users\shash\Projects\Langchain_Course\.venv\Lib\site-packages\langgraph\pregel\_runner.py:167, in PregelRunner.tick(self, tasks, reraise, timeout, retry_policy, get_waiter, schedule_task)
#     165 t = tasks[0]
#     166 try:
# --> 167     run_with_retry(
#     168         t,
#     169         retry_policy,
#     170         configurable={
#     171             CONFIG_KEY_CALL: partial(
#     172                 _call,
#     173                 weakref.ref(t),
#     174                 retry_policy=retry_policy,
#     175                 futures=weakref.ref(futures),
#     176                 schedule_task=schedule_task,
#     177                 submit=self.submit,
#     178             ),
#     179         },
#     180     )
#     181     self.commit(t, None)
#     182 except Exception as exc:
#
# File c:\Users\shash\Projects\Langchain_Course\.venv\Lib\site-packages\langgraph\pregel\_retry.py:71, in run_with_retry(task, retry_policy, configurable)
#      69     task.writes.clear()
#      70     # run the task
# ---> 71     return task.proc.invoke(task.input, config)
#      72 except ParentCommand as exc:
#      73     ns: str = config[CONF][CONFIG_KEY_CHECKPOINT_NS]
#
# File c:\Users\shash\Projects\Langchain_Course\.venv\Lib\site-packages\langgraph\_internal\_runnable.py:656, in RunnableSeq.invoke(self, input, config, **kwargs)
#     654     # run in context
#     655     with set_config_context(config, run) as context:
# --> 656         input = context.run(step.invoke, input, config, **kwargs)
#     657 else:
#     658     input = step.invoke(input, config)
#
# File c:\Users\shash\Projects\Langchain_Course\.venv\Lib\site-packages\langgraph\_internal\_runnable.py:400, in RunnableCallable.invoke(self, input, config, **kwargs)
#     398         run_manager.on_chain_end(ret)
#     399 else:
# --> 400     ret = self.func(*args, **kwargs)
#     401 if self.recurse and isinstance(ret, Runnable):
#     402     return ret.invoke(input, config)
#
# File c:\Users\shash\Projects\Langchain_Course\.venv\Lib\site-packages\langgraph\prebuilt\tool_node.py:813, in ToolNode._func(self, input, config, runtime)
#     811 input_types = [input_type] * len(tool_calls)
#     812 with get_executor_for_config(config) as executor:
# --> 813     outputs = list(
#     814         executor.map(self._run_one, tool_calls, input_types, tool_runtimes)
#     815     )
#     817 return self._combine_tool_outputs(outputs, input_type)
#
# File ~\AppData\Roaming\uv\python\cpython-3.13-windows-x86_64-none\Lib\concurrent\futures\_base.py:619, in Executor.map.<locals>.result_iterator()
#     616 while fs:
#     617     # Careful not to keep a reference to the popped future
#     618     if timeout is None:
# --> 619         yield _result_or_cancel(fs.pop())
#     620     else:
#     621         yield _result_or_cancel(fs.pop(), end_time - time.monotonic())
#
# File ~\AppData\Roaming\uv\python\cpython-3.13-windows-x86_64-none\Lib\concurrent\futures\_base.py:317, in _result_or_cancel(***failed resolving arguments***)
#     315 try:
#     316     try:
# --> 317         return fut.result(timeout)
#     318     finally:
#     319         fut.cancel()
#
# File ~\AppData\Roaming\uv\python\cpython-3.13-windows-x86_64-none\Lib\concurrent\futures\_base.py:456, in Future.result(self, timeout)
#     454     raise CancelledError()
#     455 elif self._state == FINISHED:
# --> 456     return self.__get_result()
#     457 else:
#     458     raise TimeoutError()
#
# File ~\AppData\Roaming\uv\python\cpython-3.13-windows-x86_64-none\Lib\concurrent\futures\_base.py:401, in Future.__get_result(self)
#     399 if self._exception is not None:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File ~\AppData\Roaming\uv\python\cpython-3.13-windows-x86_64-none\Lib\concurrent\futures\thread.py:59, in _WorkItem.run(self)
#      56     return
#      58 try:
# ---> 59     result = self.fn(*self.args, **self.kwargs)
#      60 except BaseException as exc:
#      61     self.future.set_exception(exc)
#
# File c:\Users\shash\Projects\Langchain_Course\.venv\Lib\site-packages\langchain_core\runnables\config.py:610, in ContextThreadPoolExecutor.map.<locals>._wrapped_fn(*args)
#     609 def _wrapped_fn(*args: Any) -> T:
# --> 610     return contexts.pop().run(fn, *args)
#
# File c:\Users\shash\Projects\Langchain_Course\.venv\Lib\site-packages\langgraph\prebuilt\tool_node.py:1024, in ToolNode._run_one(self, call, input_type, tool_runtime)
#    1020 config = tool_runtime.config
#    1022 if self._wrap_tool_call is None:
#    1023     # No wrapper - execute directly
# -> 1024     return self._execute_tool_sync(tool_request, input_type, config)
#    1026 # Define execute callable that can be called multiple times
#    1027 def execute(req: ToolCallRequest) -> ToolMessage | Command:
#
# File c:\Users\shash\Projects\Langchain_Course\.venv\Lib\site-packages\langgraph\prebuilt\tool_node.py:973, in ToolNode._execute_tool_sync(self, request, input_type, config)
#     970         raise
#     972     # Error is handled - create error ToolMessage
# --> 973     content = _handle_tool_error(e, flag=self._handle_tool_errors)
#     974     return ToolMessage(
#     975         content=content,
#     976         name=call["name"],
#     977         tool_call_id=call["id"],
#     978         status="error",
#     979     )
#     981 # Process successful response
#
# File c:\Users\shash\Projects\Langchain_Course\.venv\Lib\site-packages\langgraph\prebuilt\tool_node.py:430, in _handle_tool_error(e, flag)
#     428     content = flag
#     429 elif callable(flag):
# --> 430     content = flag(e)  # type: ignore [assignment, call-arg]
#     431 else:
#     432     msg = (
#     433         f"Got unexpected type of `handle_tool_error`. Expected bool, str "
#     434         f"or callable. Received: {flag}"
#     435     )
#
# File c:\Users\shash\Projects\Langchain_Course\.venv\Lib\site-packages\langgraph\prebuilt\tool_node.py:387, in _default_handle_tool_errors(e)
#     385 if isinstance(e, ToolInvocationError):
#     386     return e.message
# --> 387 raise e
#
# File c:\Users\shash\Projects\Langchain_Course\.venv\Lib\site-packages\langgraph\prebuilt\tool_node.py:930, in ToolNode._execute_tool_sync(self, request, input_type, config)
#     928 try:
#     929     try:
# --> 930         response = tool.invoke(call_args, config)
#     931     except ValidationError as exc:
#     932         # Filter out errors for injected arguments
#     933         injected = self._injected_args.get(call["name"])
#
# File c:\Users\shash\Projects\Langchain_Course\.venv\Lib\site-packages\langchain_core\tools\base.py:642, in BaseTool.invoke(self, input, config, **kwargs)
#     634 @override
#     635 def invoke(
#     636     self,
#    (...)    639     **kwargs: Any,
#     640 ) -> Any:
#     641     tool_input, kwargs = _prep_run_args(input, config, **kwargs)
# --> 642     return self.run(tool_input, **kwargs)
#
# File c:\Users\shash\Projects\Langchain_Course\.venv\Lib\site-packages\langchain_core\tools\base.py:1001, in BaseTool.run(self, tool_input, verbose, start_color, color, callbacks, tags, metadata, run_name, run_id, config, tool_call_id, **kwargs)
#     999 if error_to_raise:
#    1000     run_manager.on_tool_error(error_to_raise, tool_call_id=tool_call_id)
# -> 1001     raise error_to_raise
#    1002 output = _format_output(content, artifact, tool_call_id, self.name, status)
#    1003 run_manager.on_tool_end(output, color=color, name=self.name, **kwargs)
#
# File c:\Users\shash\Projects\Langchain_Course\.venv\Lib\site-packages\langchain_core\tools\base.py:967, in BaseTool.run(self, tool_input, verbose, start_color, color, callbacks, tags, metadata, run_name, run_id, config, tool_call_id, **kwargs)
#     965     if config_param := _get_runnable_config_param(self._run):
#     966         tool_kwargs |= {config_param: config}
# --> 967     response = context.run(self._run, *tool_args, **tool_kwargs)
#     968 if self.response_format == "content_and_artifact":
#     969     msg = (
#     970         "Since response_format='content_and_artifact' "
#     971         "a two-tuple of the message content and raw tool output is "
#     972         f"expected. Instead, generated response is of type: "
#     973         f"{type(response)}."
#     974     )
#
# File c:\Users\shash\Projects\Langchain_Course\.venv\Lib\site-packages\langchain_core\tools\structured.py:97, in StructuredTool._run(self, config, run_manager, *args, **kwargs)
#      95     if config_param := _get_runnable_config_param(self.func):
#      96         kwargs[config_param] = config
# ---> 97     return self.func(*args, **kwargs)
#      98 msg = "StructuredTool does not support sync invocation."
#      99 raise NotImplementedError(msg)
#
# Cell In[21], line 19, in get_favourite_colour(runtime)
#      16 @tool
#      17 def get_favourite_colour(runtime: ToolRuntime) -> str:
#      18     """Get the favourite colour of the user"""
# ---> 19     return runtime.context.favourite_colour
#
# AttributeError: 'NoneType' object has no attribute 'favourite_colour'
# During task with name 'tools' and id 'f355bcf9-b589-d318-f9a6-724ec377a29b'
